# %% [markdown]
# <a href="https://colab.research.google.com/github/antonsysoev/Ass/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library("readxl")

# %%
# %%R
# df <- as.data.frame(read_excel('/content/TimeAll.xlsx'))
# df <- df[sample(nrow(df)),]

# %%
# %%R
# head(df)
# Out:
#       Type_of_accident Gender Social_character Direct_traffic_violations
# 7903                 2      1                1                         7
# 12735                2      1                2                         7
# 2929                 1      1                2                         4
# 10884                2      1                1                         1
# 7524                 2      1                1                         1
# 2652                 1      1                2                        10
#       Concomitant_traffic_violations Experience      Age
# 7903                               2          2 24.44658
# 12735                              2         18 52.62192
# 2929                               2         39 65.67397
# 10884                              2          3 20.95342
# 7524                               2          1 18.46849
# 2652                               2         11 33.20000

# %%
# %%R
# install.packages("neuralnet")
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/neuralnet_1.44.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 27211 bytes (26 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
#
# library(neuralnet)
# summary(df)
# Out:
#  Type_of_accident     Gender     Social_character   Direct_traffic_violations
#  Min.   :1.0      Min.   :1.00   Length:13634       Min.   : 1.000
#  1st Qu.:1.0      1st Qu.:1.00   Class :character   1st Qu.: 1.000
#  Median :1.5      Median :1.00   Mode  :character   Median : 4.000
#  Mean   :1.5      Mean   :1.17                      Mean   : 4.135
#  3rd Qu.:2.0      3rd Qu.:1.00                      3rd Qu.: 7.000
#  Max.   :2.0      Max.   :3.00                      Max.   :28.000
#  Concomitant_traffic_violations   Experience         Age
#  Min.   : 2.00                  Min.   : 0.00   Min.   :17.20
#  1st Qu.: 2.00                  1st Qu.: 4.00   1st Qu.:25.91
#  Median : 2.00                  Median :10.00   Median :32.47
#  Mean   : 3.02                  Mean   :12.46   Mean   :35.29
#  3rd Qu.: 2.00                  3rd Qu.:18.00   3rd Qu.:42.67
#  Max.   :30.00                  Max.   :68.00   Max.   :87.84

# %%
# %%R
#
# df_0 <- head(df,2000)

# %%
# %%R
# install.packages("nnet")
# library(nnet)
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/nnet_7.3-16.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 29097 bytes (28 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
#
# neural_net <- nnet(Type_of_accident ~ Age + Experience,  data = df_0, size = 100)
# Out:
# # weights:  401
# initial  value 4020.114023
# final  value 969.000000
# converged

# %%
# %%R
#
# neural_net$fitted.values
# Out:
#       [,1]
# 7903     1
# 12735    1
# 2929     1
# 10884    1
# 7524     1
# 2652     1
# 4513     1
# 9518     1
# 6651     1
# 11875    1
# 11218    1
# 10240    1
# 6734     1
# 10258    1
# 13415    1
# 4444     1
# 11381    1
# 11517    1
# 430      1
# 2756     1
# 4831     1
# 1612     1
# 10236    1
# 5684     1
# 8191     1
# 8712     1
# 6349     1
# 7148     1
# 6943     1
# 11335    1
# 6442     1
# 438      1
# 9636     1
# 8378     1
# 1124     1
# 8620     1
# 8215     1
# 13543    1
# 8686     1
# 12231    1
# 9749     1
# 9496     1
# 6246     1
# 3389     1
# 7363     1
# 9848     1
# 6515     1
# 8773     1
# 5027     1
# 5015     1
# 4314     1
# 2903     1
# 9048     1
# 6558     1
# 6864     1
# 6122     1
# 3047     1
# 10208    1
# 8014     1
# 6030     1
# 13535    1
# 11519    1
# 10195    1
# 12461    1
# 6094     1
# 10286    1
# 2827     1
# 11779    1
# 1337     1
# 2164     1
# 5653     1
# 3877     1
# 10814    1
# 4762     1
# 3422     1
# ...
